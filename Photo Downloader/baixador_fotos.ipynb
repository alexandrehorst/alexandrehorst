# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time, os
import urllib.request
from credentials import user, password


# Função que verifica se determinado diretório exsite 
def verifica_e_cria_diretorio(diretorio):
    if not os.path.exists(diretorio):
        os.makedirs(diretorio)
        print(f'Diretório {diretorio} criado com sucesso.')
    else:
        print(f'O diretório {diretorio} já existe.')      


# Diretórios para salvamento das fotos        
dir_mat1 = 'C:\\Users\\Alexandre\\Downloads\\Fotos Viva\\Mat1'
dir_pre2 = 'C:\\Users\\Alexandre\\Downloads\\Fotos Viva\\Pre2'
        
# Cria diretórios para salvamentos das fotos
verifica_e_cria_diretorio(dir_mat1)
verifica_e_cria_diretorio(dir_pre2)

# Abre o navegador no site
url = 'https://online.vivasistemas.com/login'
navegador = webdriver.Chrome()
navegador.get(url)
time.sleep(10)

# Encontre o campo de login e insira o login
login_input = navegador.find_element('xpath', '//*[@id="email"]')
login_input.send_keys(user)

# Encontre o campo de senha e insira a senha
senha_input = navegador.find_element('xpath', '//*[@id="password"]')
senha_input.send_keys(password)

# Envie o formulário (pode ser um clique em um botão de login também, dependendo do site)
senha_input.send_keys(Keys.ENTER)
time.sleep(10)
# Seleciona Beatriz e Guilherme (xpath do botão selecionado)
xpath_filhos = ['/html/body/app-root/app-filhos/div/div[2]/div/div/div[2]/div/div[2]/button', '/html/body/app-root/app-filhos/div/div[2]/div/div/div[3]/div/div[2]/button']

count = 0
for xp in xpath_filhos:
    # Depois de baixar a fotos do primeiro filho retorna para o menu inicial
    if count == 1:
        # Clica no link Filhos
        #navegador.find_element('xpath', '//*[@id="side-menu"]/li[2]/a').click()
        navegador.find_element('xpath', '//*[@id="side-menu"]/li[2]/a/span').click()
        time.sleep(20)
    
    seleciona_filho = navegador.find_element('xpath', xp).send_keys(Keys.ENTER)
    time.sleep(30)

    # Clica no link portifólio
    seleciona_portifolio = navegador.find_element('xpath', '//*[@id="side-menu"]/li[5]/a/span').click()
    time.sleep(30)

    # Encontre todos os elementos de link da página:
    elementos_img = navegador.find_element(By.TAG_NAME, "app-root")

    # Verificar o que há dentro do WebElement
    #conteudo_elemento = elementos_img.get_attribute("innerText") # Formato Texto
    conteudo_elemento = elementos_img.get_attribute("innerHTML") # Formato HTML
    time.sleep(30)

    # Cria um objeto BeautifulSoup com o conteúdo HTML
    soup = BeautifulSoup(conteudo_elemento, "html.parser")

    # Busca todos os links de imagens dentro do WebElement
    links_imagens = soup.find_all("img")
    print(len(links_imagens)) # quantidade de fotos do link

    timeout = 120
    # Percorre a lista com os links e baixa todas as fotos 
    for link in links_imagens:
        url = link.get("src")
        print(link.get("src"))
        # Abre a URL com um timeout
        if url.startswith('https:'):
            try:
                # Extrai o nome da imagem do URL
                nome_arquivo = url.split("/")[-1]
                response = urllib.request.urlopen(url, timeout=timeout)
                # Se a solicitação for bem-sucedida, baixe o arquivo                
                if count == 0:  # Separa os diretórios nos quais as fotos serão salvas
                    # Caso o arquivo não exista dentro do diretório, o arquivo será salvo
                    if not os.path.isfile(f'{dir_mat1}\\{nome_arquivo}'):
                        with open(f'{dir_mat1}\\{nome_arquivo}', 'wb') as file:
                            file.write(response.read())
                        print(f"{nome_arquivo} baixado com sucesso!")
                else:
                    # Caso o arquivo não exista dentro do diretório, o arquivo será salvo
                    if not os.path.isfile(f'{dir_pre2}\\{nome_arquivo}'):
                        with open(f'{dir_pre2}\\{nome_arquivo}', 'wb') as file:
                            file.write(response.read())
                        print(f"{nome_arquivo} baixado com sucesso!")                
            except urllib.error.URLError as e:
                print(f"Erro de URL: {e.reason}")
            except socket.timeout:
                print("Tempo limite de solicitação atingido. A conexão foi interrompida.")
    count += 1
    time.sleep(15)

# Fecha o navegador
navegador.quit()

print('Download das fotos concluído!')
# Out:
# O diretório C:\Users\Alexandre\Downloads\Fotos Viva\Mat1 já existe.
# O diretório C:\Users\Alexandre\Downloads\Fotos Viva\Pre2 já existe.
# 74
# assets/images/logo-otimizado.png
# https://vivaimagens.blob.core.windows.net/imagens/chat/KWLbRDMltY.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/zeLE6Y8mfI.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/MBgWsI974K.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/yTdcTU6jZa.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/Zb3EgaqeOl.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/2g2KReAXkl.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/tRoTZOc7b0.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/CD9TcXorAM.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/ImRp8WUoVz.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/x11nkuujks.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/pUFlQ1KZZs.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/zo8Rm8Keet.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/VRKN61rZ0q.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/uv1zFeEvS0.jpg
# uv1zFeEvS0.jpg baixado com sucesso!
# https://vivaimagens.blob.core.windows.net/imagens/chat/yDPRXviCkT.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/I0ZCru84SB.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/BnYV5dLqnI.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/IsN0pspYmS.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/48R0YfasbL.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/1Z4kr8asZH.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/YrapVvFSN8.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/IZgnBpkYLc.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/2Zb1PC9XrZ.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/c3XnNgjFh7.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/zRk2DW3KwL.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/AGEVA52d5A.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/OIPh0xlEEQ.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/DSpEp4mojM.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/YnoRX0XSnX.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/piG8LuEymm.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/V2grjVjEQA.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/WGzEOCGDex.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/Xpn2bBi7qy.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/0noMqQ4TdA.jpg
# 0noMqQ4TdA.jpg baixado com sucesso!
# https://vivaimagens.blob.core.windows.net/imagens/chat/ntUQdI9DMS.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/bEOcct3zFQ.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/zsCg64RLww.jpg
# zsCg64RLww.jpg baixado com sucesso!
# https://vivaimagens.blob.core.windows.net/imagens/chat/c7aLnr3Hyq.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/TPpSicaW6F.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/Q3dTneLJtl.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/DurnPUO3V8.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/f78AZl49Du.jpg
# f78AZl49Du.jpg baixado com sucesso!
# https://vivaimagens.blob.core.windows.net/imagens/chat/2Nzl5af3vP.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/VnFFpesFkC.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/EoySmUpaxu.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/MTdUEEFnNb.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/hAgh31MSrh.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/6k9lS0y8Yu.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/g8k2FstCmy.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/GpbPUI3uUM.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/KpfbFgrgzD.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/Khgqd7MbLt.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/uIXfQqCoNZ.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/q9omQxQvl2.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/ydnQ4eS0JR.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/tP1m2pJMxC.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/HqT9ysrOYR.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/73bTCBHbmO.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/tBWpm6I9ub.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/wO9KrWUo0G.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/PCuQSgFPtc.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/ZbfZK6pc4V.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/akeATMagYe.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/gdf3dsgklO.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/BzumFmlbdR.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/ASdIHYvtbE.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/vjS3LqeCna.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/fVK6oz0pyx.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/zUnogk8nDn.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/DZ7LfPjmPC.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/EOvqHR6JFV.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/4Jmg2WLFvl.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/Fr8WqDAvKE.jpg
# 158
# assets/images/logo-otimizado.png
# https://vivaimagens.blob.core.windows.net/imagens/chat/DVXcrwO0Gy.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/Qx04lDzeyy.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/AKDeOjkDqV.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/0rJmeGkTh2.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/v0Oe0W4S4j.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/YBsNteK7Lu.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/fWn8u0UyNU.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/bol5CXZTLX.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/A9XchTO3Ed.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/PCCAPUioVY.jpg
# PCCAPUioVY.jpg baixado com sucesso!
# https://vivaimagens.blob.core.windows.net/imagens/chat/NhhzyoJheB.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/2cqQHCT2CM.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/8NrVizGQSm.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/IOBnCUZsFe.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/YkDYYX5MW2.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/pzbFjyZHvF.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/8WQxcxvnxC.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/J4dqh3DXwY.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/KzAqpUIXTs.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/RfRDmlqlvd.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/OioMF1RVzK.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/kCmxI2ftxE.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/FEJH32601Y.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/kRxGD0Rvqk.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/by0wcSDqke.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/Mv4pFV4Txn.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/G6ewg3E8lK.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/OFMd59wk83.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/CqLGTKhTuh.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/Rlr0QlTlsz.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat/B00VzCaKCC.jpg
# https://vivaimagens.blob.core.windows.net/imagens/chat